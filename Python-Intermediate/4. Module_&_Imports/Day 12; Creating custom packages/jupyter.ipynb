# %%
import my_pkg
# Out:
# My name is: empty_2.helper2
# Greetings of the day, Hello from helper.py!
# this is __init__.py file in empty_2 package

# %%
print(my_pkg.greet())
# Out:
# Hello from helper.py

# %%
print(my_pkg.hello("World"))
# Out:
# Hello, World!
# None

# %%
print(my_pkg.helper2.b)
# Out:
# Greetings of the day, Hello from helper.py!
